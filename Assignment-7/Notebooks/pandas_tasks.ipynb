# %%
import pandas as pd
data = {
    "Name": ["Dinmukhamed", "Imran", "Suleiman", "Miroslav", "Dair"],
    "Age": [21, 20, 20, 20, 21],
    "Score": [85, 80, 90, 88, 95]
}

df = pd.DataFrame(data)
print(df)
print(df.head(3))
print(df.describe())
avrg = df["Score"].mean()
print(avrg)
print(df[df["Age"] > 20])
print(df[df["Score"] > 80])
# Out:
#           Name  Age  Score
# 0  Dinmukhamed   21     85
# 1        Imran   20     80
# 2     Suleiman   20     90
# 3     Miroslav   20     88
# 4         Dair   21     95
#           Name  Age  Score
# 0  Dinmukhamed   21     85
# 1        Imran   20     80
# 2     Suleiman   20     90
#              Age     Score
# count   5.000000   5.00000
# mean   20.400000  87.60000
# std     0.547723   5.59464
# min    20.000000  80.00000
# 25%    20.000000  85.00000
# 50%    20.000000  88.00000
# 75%    21.000000  90.00000
# max    21.000000  95.00000
# 87.6
#           Name  Age  Score
# 0  Dinmukhamed   21     85
# 4         Dair   21     95
#           Name  Age  Score
# 0  Dinmukhamed   21     85
# 2     Suleiman   20     90
# 3     Miroslav   20     88
# 4         Dair   21     95
